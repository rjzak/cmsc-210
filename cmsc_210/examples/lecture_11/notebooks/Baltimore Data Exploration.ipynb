# %% [markdown]
# # Exploring Baltimore City 311 Requests
#
# There are two data sets:
#
# * [Baltimore 311](https://311services.baltimorecity.gov/) service reqeusts for the year 2019 (source: [Open Baltimore](https://data.baltimorecity.gov/City-Services/311-Customer-Service-Requests/9agw-sxsr))
# * 2010 US Census population data by City Council District (source: [US Census Data](https://planning.baltimorecity.gov/sites/default/files/Demographic%20Data%20by%20Council%20District.pdf))

# %%
from matplotlib import pyplot
import pandas 
import seaborn 


requests = pandas.read_csv("311_Customer_Service_Requests.csv", 
                           index_col="ServiceRequestNum",
                           parse_dates=["CreatedDate", "CloseDate"],
                           infer_datetime_format=True,
                           dtype={"ZipCode": "str", "CouncilDistrict": "str"})
requests
# Out:
#                                        SRType MethodReceived  \
# ServiceRequestNum
# 19-00370157                   SW-Dirty Street          Phone
# 19-00369213             WW-Water Low Pressure          Phone
# 19-00364711                  TRM-Grass Mowing            API
# 19-00380006                 SW-Bulk Scheduled          Phone
# 19-00377074                   TRM-Curb Repair          Phone
# ...                                       ...            ...
# 19-00243068                      FCCS-Refunds          Phone
# 19-00244528                TRM-Pickup Pothole       Internal
# 19-00239333                   SW-Dirty Street          Phone
# 19-00254426        WW-Sewer Water In Basement          Phone
# 19-00255178                    SW-Dirty Alley            API
#
#                           CreatedDate            SRStatus           CloseDate  \
# ServiceRequestNum
# 19-00370157       2019-07-02 08:00:32              Closed 2019-07-03 13:01:27
# 19-00369213       2019-07-01 15:37:37              Closed 2019-07-17 12:19:15
# 19-00364711       2019-06-29 08:56:10              Closed 2019-07-16 14:57:16
# 19-00380006       2019-07-05 15:36:33              Closed 2019-07-19 16:32:35
# 19-00377074       2019-07-04 10:00:03  Closed (Duplicate) 2019-07-09 15:47:01
# ...                               ...                 ...                 ...
# 19-00243068       2019-04-29 10:49:53                Open                 NaT
# 19-00244528       2019-04-29 15:49:02              Closed 2019-04-29 15:49:36
# 19-00239333       2019-04-26 15:37:45              Closed 2019-06-24 11:43:41
# 19-00254426       2019-05-02 15:46:32              Closed 2019-05-03 13:53:24
# 19-00255178       2019-05-02 23:36:34              Closed 2019-09-25 16:43:51
#
#                              Agency  \
# ServiceRequestNum
# 19-00370157             Solid Waste
# 19-00369213        Water Wastewater
# 19-00364711          Transportation
# 19-00380006             Solid Waste
# 19-00377074          Transportation
# ...                             ...
# 19-00243068                 Finance
# 19-00244528          Transportation
# 19-00239333             Solid Waste
# 19-00254426        Water Wastewater
# 19-00255178             Solid Waste
#
#                                                              Outcome ZipCode  \
# ServiceRequestNum
# 19-00370157                                           Work completed   21224
# 19-00369213        SR closed by agency-specific work management s...   21221
# 19-00364711                                           Work completed   21230
# 19-00380006                                                      NaN   21239
# 19-00377074                                                      NaN   21229
# ...                                                              ...     ...
# 19-00243068                                                      NaN   21222
# 19-00244528                                           Work completed   21217
# 19-00239333           SR assessed and no cause for action determined   21230
# 19-00254426        SR closed by agency-specific work management s...   21229
# 19-00255178                                           Work completed   21230
#
#                         Neighborhood CouncilDistrict   Latitude  Longitude
# ServiceRequestNum
# 19-00370157             Highlandtown               1  39.288463 -76.571855
# 19-00369213                      NaN             NaN  39.284260 -76.444584
# 19-00364711        Ridgely's Delight              11  39.285555 -76.624816
# 19-00380006             Perring Loch               3  39.352273 -76.584500
# 19-00377074                Allendale               8  39.291770 -76.681235
# ...                              ...             ...        ...        ...
# 19-00243068                      NaN             NaN  39.274063 -76.471778
# 19-00244528                Mondawmin               7  39.311093 -76.648379
# 19-00239333              Cherry Hill              10  39.243852 -76.632539
# 19-00254426               West Hills               8  39.297163 -76.711140
# 19-00255178             Federal Hill              11  39.278407 -76.614081
#
# [768548 rows x 12 columns]

# %% [markdown]
# ## What are some questions we can answer with this data?
#
# 1. What is the average number of days a request takes from being opened to being closed?
# 2. Which city agencies handle the most requests?
# 3. How does the volume of requests change over time?
# 4. Which city council districts handle the most requests?
# 5. Does the number of vacanct houses in a city council district correlate with the volume of requests?
# 6. Are there "request hotspots"?
#
# _Let's get to work..._

# %%
seaborn.set_theme(style="darkgrid")
seaborn.set_context("talk")


# Let's add a column with the number of days the request was open. 
# We have an "open date" and a "close date". Or at least we should...
print("There are {:,} rows with missing close dates.".format(requests.CloseDate.isna().sum()))

# We'll create a new column here, just realizing that there will be some NaN (not-a-number) values in it.
requests["DaysOpen"] = (requests.CloseDate - requests.CreatedDate).dt.days
requests
# Out:
# There are 10,153 rows with missing close dates.
#                                        SRType MethodReceived  \
# ServiceRequestNum
# 19-00370157                   SW-Dirty Street          Phone
# 19-00369213             WW-Water Low Pressure          Phone
# 19-00364711                  TRM-Grass Mowing            API
# 19-00380006                 SW-Bulk Scheduled          Phone
# 19-00377074                   TRM-Curb Repair          Phone
# ...                                       ...            ...
# 19-00243068                      FCCS-Refunds          Phone
# 19-00244528                TRM-Pickup Pothole       Internal
# 19-00239333                   SW-Dirty Street          Phone
# 19-00254426        WW-Sewer Water In Basement          Phone
# 19-00255178                    SW-Dirty Alley            API
#
#                           CreatedDate            SRStatus           CloseDate  \
# ServiceRequestNum
# 19-00370157       2019-07-02 08:00:32              Closed 2019-07-03 13:01:27
# 19-00369213       2019-07-01 15:37:37              Closed 2019-07-17 12:19:15
# 19-00364711       2019-06-29 08:56:10              Closed 2019-07-16 14:57:16
# 19-00380006       2019-07-05 15:36:33              Closed 2019-07-19 16:32:35
# 19-00377074       2019-07-04 10:00:03  Closed (Duplicate) 2019-07-09 15:47:01
# ...                               ...                 ...                 ...
# 19-00243068       2019-04-29 10:49:53                Open                 NaT
# 19-00244528       2019-04-29 15:49:02              Closed 2019-04-29 15:49:36
# 19-00239333       2019-04-26 15:37:45              Closed 2019-06-24 11:43:41
# 19-00254426       2019-05-02 15:46:32              Closed 2019-05-03 13:53:24
# 19-00255178       2019-05-02 23:36:34              Closed 2019-09-25 16:43:51
#
#                              Agency  \
# ServiceRequestNum
# 19-00370157             Solid Waste
# 19-00369213        Water Wastewater
# 19-00364711          Transportation
# 19-00380006             Solid Waste
# 19-00377074          Transportation
# ...                             ...
# 19-00243068                 Finance
# 19-00244528          Transportation
# 19-00239333             Solid Waste
# 19-00254426        Water Wastewater
# 19-00255178             Solid Waste
#
#                                                              Outcome ZipCode  \
# ServiceRequestNum
# 19-00370157                                           Work completed   21224
# 19-00369213        SR closed by agency-specific work management s...   21221
# 19-00364711                                           Work completed   21230
# 19-00380006                                                      NaN   21239
# 19-00377074                                                      NaN   21229
# ...                                                              ...     ...
# 19-00243068                                                      NaN   21222
# 19-00244528                                           Work completed   21217
# 19-00239333           SR assessed and no cause for action determined   21230
# 19-00254426        SR closed by agency-specific work management s...   21229
# 19-00255178                                           Work completed   21230
#
#                         Neighborhood CouncilDistrict   Latitude  Longitude  \
# ServiceRequestNum
# 19-00370157             Highlandtown               1  39.288463 -76.571855
# 19-00369213                      NaN             NaN  39.284260 -76.444584
# 19-00364711        Ridgely's Delight              11  39.285555 -76.624816
# 19-00380006             Perring Loch               3  39.352273 -76.584500
# 19-00377074                Allendale               8  39.291770 -76.681235
# ...                              ...             ...        ...        ...
# 19-00243068                      NaN             NaN  39.274063 -76.471778
# 19-00244528                Mondawmin               7  39.311093 -76.648379
# 19-00239333              Cherry Hill              10  39.243852 -76.632539
# 19-00254426               West Hills               8  39.297163 -76.711140
# 19-00255178             Federal Hill              11  39.278407 -76.614081
#
#                    DaysOpen
# ServiceRequestNum
# 19-00370157             1.0
# 19-00369213            15.0
# 19-00364711            17.0
# 19-00380006            14.0
# 19-00377074             5.0
# ...                     ...
# 19-00243068             NaN
# 19-00244528             0.0
# 19-00239333            58.0
# 19-00254426             0.0
# 19-00255178           145.0
#
# [768548 rows x 13 columns]

# %% [markdown]
# ### Days to satisfy requests by city agency

# %%
# Let's aggregate some data by city agency. 
# We'll calculate a count of requests, max value, and median value for "DaysOpen" by agency
by_agency = requests.groupby(by="Agency").DaysOpen.aggregate(["count", "max", "median", "mean"]).reset_index()

by_agency
# Out:
#                 Agency   count    max  median        mean
# 0                 BCIT      18   85.0     8.0   23.944444
# 1                  BGE   26473  534.0     0.0    5.897216
# 2          Call Center   75114  360.0     0.0    1.309556
# 3         City Council       0    NaN     NaN         NaN
# 4              Finance   25830  628.0   202.0  198.328533
# 5      Fire Department    4058  495.0     0.0   16.864712
# 6     General Services       7   64.0    32.0   33.000000
# 7               Health   21064  289.0     0.0    1.306400
# 8              Housing   79836  362.0     2.0    4.032141
# 9         Liquor Board     675   20.0     0.0    0.342222
# 10      Mayor's Office      19   28.0     7.0    9.578947
# 11   Parking Authority    1237  211.0     2.0    7.143897
# 12   Police Department       0    NaN     NaN         NaN
# 13      Public Schools       0    NaN     NaN         NaN
# 14        Public Works     351  272.0     6.0   22.994302
# 15  Recreation & Parks   11396  638.0    22.0   70.966830
# 16         Solid Waste  354602  485.0     1.0   17.234342
# 17      Transportation  114067  579.0     0.0   12.365285
# 18    Water Wastewater   43647  559.0     2.0   25.661328

# %% [markdown]
# _What are some issues with this data?_ How might we fix them?
#
# * Some agencies handle a tiny number of requests. Solution: filter out agencies that handle less than 200 requests per year.
# * Some agencies never seem to resolve their tickets. Solution: filter out agencies where the median number of days a ticket is > 200
# * Some agencies seem to close most of their tickets immediately (< 1 day). Solution: filter out agencies wgere median number of days is 0

# %%
# These agencies we will treat as outliers:
by_agency[(by_agency["count"] < 200) | (by_agency["median"] == 0.0) | (by_agency["median"] > 200)]
# Out:
#                Agency   count    max  median        mean
# 0                BCIT      18   85.0     8.0   23.944444
# 1                 BGE   26473  534.0     0.0    5.897216
# 2         Call Center   75114  360.0     0.0    1.309556
# 3        City Council       0    NaN     NaN         NaN
# 4             Finance   25830  628.0   202.0  198.328533
# 5     Fire Department    4058  495.0     0.0   16.864712
# 6    General Services       7   64.0    32.0   33.000000
# 7              Health   21064  289.0     0.0    1.306400
# 9        Liquor Board     675   20.0     0.0    0.342222
# 10     Mayor's Office      19   28.0     7.0    9.578947
# 12  Police Department       0    NaN     NaN         NaN
# 13     Public Schools       0    NaN     NaN         NaN
# 17     Transportation  114067  579.0     0.0   12.365285

# %%
filtered_agencies = by_agency[(by_agency["count"] >= 200) & (by_agency["median"] > 0) & (by_agency["median"] <= 200)]
# Used to set the size of the graphic.
fig, ax = pyplot.subplots(figsize=(25, 8))
seaborn.barplot(data=filtered_agencies, x="Agency", y="median", ax=ax)
ax.set(ylabel='Median days open')
# Out:
# [Text(0, 0.5, 'Median days open')]

# %% [markdown]
# ### Timeseries Data

# %%
time_series = requests.groupby(requests.CreatedDate.dt.date).size()
fig, ax = pyplot.subplots(figsize=(25, 8))
seaborn.lineplot(data=time_series, ax=ax)
# Out:
# <AxesSubplot:xlabel='CreatedDate'>

# %% [markdown]
# With time series data, cyclical patterns can sometimes obscure trends in the data. A simple way to "remove" a cyclical pattern (if you know the length of the cycle) is to apply a [rolling average](https://en.wikipedia.org/wiki/Moving_average)

# %%
smoothed_time_series = time_series.rolling(7).sum()
fig, ax = pyplot.subplots(figsize=(25, 8))
seaborn.lineplot(data=smoothed_time_series, ax=ax)
# Out:
# <AxesSubplot:xlabel='CreatedDate'>

# %% [markdown]
# ### Volume of requests by district

# %%
requests_by_district = requests.groupby(requests.CouncilDistrict).size().reset_index(name="RequestCount")
# Let's sort the dataframe and chart we get from it in order of ascending number of requests:
requests_by_district.sort_values("RequestCount", inplace=True)
fig, ax = pyplot.subplots(figsize=(25, 8))
seaborn.barplot(data=requests_by_district, x="CouncilDistrict", y="RequestCount", ax=ax)
# Out:
# <AxesSubplot:xlabel='CouncilDistrict', ylabel='RequestCount'>

# %% [markdown]
# Can you see any problems with presenting the data this way? How can we do a better job?
#
# Let's show number of tickets per capita in each district. We'll read in a new DataFrame with the number of people living in each district and join this to the data frame we already have.

# %%
district_demographics = pandas.read_csv("Baltimore_Council_District_Demographics.csv", dtype={"CouncilDistrict": "str"})

requests_by_district = requests.groupby(requests.CouncilDistrict).size().reset_index(name="RequestCount")

all_districts = pandas.merge(district_demographics, requests_by_district, on="CouncilDistrict")
all_districts["RequestsPerCapita"] = all_districts.RequestCount / all_districts.Population
all_districts.sort_values("RequestsPerCapita", inplace=True)

fig, ax = pyplot.subplots(figsize=(25, 8))
seaborn.barplot(data=all_districts, x="CouncilDistrict", y="RequestsPerCapita", ax=ax)
# Out:
# <AxesSubplot:xlabel='CouncilDistrict', ylabel='RequestsPerCapita'>

# %% [markdown]
# ### Correlation between volume of requests and vacancy rate
#
# Is there any connection between the number of requests per person and the percentage of vacant housing in a district.

# %%
all_districts = all_districts.assign(PercentVacant=all_districts.VacantUnits / all_districts.HousingUnits * 100)
seaborn.relplot(x="PercentVacant", y="RequestCount", data=all_districts, height=7, aspect=2.5)

# %%
seaborn.lmplot(x="PercentVacant", y="RequestCount", data=all_districts, height=7, aspect=2.5)

# %% [markdown]
# ### Finding request "hot spots"

# %%
import folium
from folium.plugins import HeatMap

baltimore_map = folium.Map(location=[39.28538, -76.61734], zoom_start=12)

heatmap_data = []
for _, row in requests[requests.CreatedDate.dt.month == 2].iterrows():
    if pandas.notna(row.Latitude) and pandas.notna(row.Longitude):
        heatmap_data.append((row.Latitude, row.Longitude))
    
# Plot it on the map
heatmap = HeatMap(heatmap_data, min_opacity=0.9, radius=5)
heatmap.add_to(baltimore_map)

baltimore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_20cfbec3fb1c4b10b83cb7878e4ad85f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_20cfbec3fb1c4b10b83cb7878e4ad85f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_20cfbec3fb1c4b10b83cb7878e4ad85f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_20cfbec3fb1c4b10b83cb7878e4ad85f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
